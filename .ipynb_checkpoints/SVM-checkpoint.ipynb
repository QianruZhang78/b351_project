# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.svm import SVC

# %%
df = pd.read_csv("dataset.csv", index_col = 0)
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2002-01-23    0.333760    0.352745    0.330545    0.352438  443279200
# 2002-01-24    0.350754    0.359940    0.350601    0.355347  344002400
# 2002-01-25    0.350448    0.358562    0.346927    0.355960  185914400
# 2002-01-28    0.358256    0.360553    0.347845    0.356266  186446400
# 2002-01-29    0.355500    0.360399    0.349836    0.353204  240324000
# ...                ...         ...         ...         ...        ...
# 2021-11-29  159.369995  161.190002  158.789993  160.240005   88748200
# 2021-11-30  159.990005  165.520004  159.919998  165.300003  174048100
# 2021-12-01  167.479996  170.300003  164.529999  164.770004  152052500
# 2021-12-02  158.740005  164.199997  157.800003  163.759995  136739200
# 2021-12-03  164.020004  164.960007  159.720001  161.839996  113912994
#
#               Return    Vol-5d      MACD        RSI         EMA        MFI  \
# Date
# 2002-01-23  0.054994  0.050050  0.001683  56.879586    0.337801  46.200427
# 2002-01-24  0.008254  0.035992  0.002980  57.971201    0.340991  43.558844
# 2002-01-25  0.001725  0.030221  0.004011  58.211280    0.343713  37.623011
# 2002-01-28  0.000860  0.004042  0.004798  58.339253    0.345995  43.231508
# 2002-01-29 -0.008596  0.005726  0.005115  56.475804    0.347306  45.017739
# ...              ...       ...       ...        ...         ...        ...
# 2021-11-29  0.021874  0.037867  3.338364  64.995963  157.618498  75.589781
# 2021-11-30  0.031578  0.034067  3.757074  71.386106  159.015135  78.049987
# 2021-12-01 -0.003206  0.017949  4.000029  69.945772  160.061475  84.204852
# 2021-12-02 -0.006130  0.018591  4.064224  67.164616  160.733933  78.305630
# 2021-12-03 -0.011724  0.019047  3.915040  62.108954  160.935035  79.122929
#
#             signal
# Date
# 2002-01-23     0.0
# 2002-01-24     0.0
# 2002-01-25     0.0
# 2002-01-28     0.0
# 2002-01-29     0.0
# ...            ...
# 2021-11-29     1.0
# 2021-11-30     1.0
# 2021-12-01     0.0
# 2021-12-02     0.0
# 2021-12-03     0.0
#
# [5001 rows x 12 columns]

# %%
X = df.drop(['Close','Open',"High", "Low", "signal"], axis = 1)
y = df['signal']

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y, train_size = 0.6)

# %%
SVM_model = SVC(gamma = 'auto')

# %%
SVM_model.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
SVM_model.score(X_test, y_test)
# Out:
# 0.4912543728135932
